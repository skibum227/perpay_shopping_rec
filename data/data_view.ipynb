# %%
import pandas as pd

# %%
# set to none display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("product_catalog.csv")

# %%
all_unique_categories = pd.concat([
    df["category_name_1"].dropna(),
    df["category_name_2"].dropna(),
    df["category_name_3"].dropna(),
    df["category_name_4"].dropna()
]).unique().tolist()
print(all_unique_categories)
# Out:
# ['Auto', 'Home', 'Outdoor Living & Garden', 'Baby & Kids', 'Clothing, Shoes & Accessories', 'Handbags & Jewelry', 'Lifestyle & Recreation', 'Electronics', 'Toys & Baby', 'Fashion & Beauty', 'Kitchen & Dining', 'Beauty', 'Lifestyle', 'Fashion', 'Pet', 'Audio/Video', 'Lawn & Garden', 'Tires', 'Recreation', 'Shoes', 'Outdoor Furniture & Decor', 'Lighting', 'Fashion Jewelry', 'Wearable Technology', 'Rugs & Decor', "Women's Clothing", 'Toys', 'Furniture', 'Women', 'Computers', 'Glassware & Barware', 'Baby', 'Handbags & Wallets', 'Personal Audio & Video', 'Fragrance', 'Household Essentials', 'Dinnerware & Serveware', 'Hobbies & Crafts', 'Cookware & Bakeware', 'Hair Care', 'Watches', 'TVs & Entertainment', 'Personal Care', "Men's Clothing", 'Outdoor Tools & Equipment', 'Grills & Outdoor Cooking', 'Kitchen Appliances', 'Furniture & Decor', 'Bedding & Bath', 'Video Games', 'Fine Jewelry', 'Sunglasses', 'Heating & Cooling', 'Home Improvement', 'Large Appliances', 'Men', 'Sports', 'Flatware & C
# ...

# %%
df.head(1)
# Out:
#    product_id                          name product_added_date   brand  \
# 0      417366  Adesso - Orbit 1120 Dash Cam         2024-09-04  Adesso
#
#   current_vendor category_name_1 request_path_1 category_name_2  \
# 0            D&H            Auto           auto     Audio/Video
#
#   request_path_2 category_name_3    request_path_3 category_name_4  \
# 0     auto/audio       Dash Cams  auto/audio/video             NaN
#
#   request_path_4                                 product_url  \
# 0            NaN  https://app.perpay.com/shop/product/417366
#
#    parent_product_id  current_price  current_cost  current_margin  \
# 0                NaN         141.99         82.13           59.86
#
#    current_ship_price    msrp  comparable_price  current_inventory  \
# 0               16.99  119.99            119.99                  7
#
#   current_status  distinct_users_viewed_30  distinct_users_viewed_60  \
# 0       Disabled                        69                       329
#
# ...

# %%
df.head()
# Out:
#             refund_count  total_orders  return_rate
# product_id
# 429015                 3             6     0.500000
# 418736                 4            12     0.333333
# 388014                 4            13     0.307692
# 414174                 5            17     0.294118
# 436081                 2             7     0.285714

# %%
users_df = pd.read_csv("user_order_history.csv")

# %%
users_df.head()
# Out:
#    user_id  order_id order_carted_date order_checkout_date order_denied_date  \
# 0     6456   9187009        2025-06-30          2025-06-30               NaN
# 1    25844   9187819        2025-06-30          2025-06-30               NaN
# 2    25844   9187819        2025-06-30          2025-06-30               NaN
# 3    25844   9187819        2025-06-30          2025-06-30               NaN
# 4    38948   9183274        2025-06-30          2025-06-30               NaN
#
#   order_approved_date order_in_repayment_date order_refunded_date  \
# 0          2025-06-30              2025-06-30                 NaN
# 1          2025-06-30              2025-06-30                 NaN
# 2          2025-06-30              2025-06-30                 NaN
# 3          2025-06-30              2025-06-30                 NaN
# 4          2025-06-30              2025-06-30                 NaN
#
#   order_canceled_date order_complete_date  product_id
# ...

# %%
products = pd.read_csv("product_catalog.csv")

# %%
products.head(10)
# Out:
#    product_id                                               name  \
# 0      417366                       Adesso - Orbit 1120 Dash Cam
# 1      306271  PetSafe - Rechargeable Fence System 14 gauge W...
# 2      409248  Bloem - Mathers Round Planter with Saucer Tray...
# 3      334555        Yokohama - Geolandar M/T G003 - LT255/75R17
# 4      339738             ScooterX - Dirt Dog 49cc Scooter - Red
# 5      376128      Lugz - Men's Drifter 6 ST Boot - Black - 11.0
# 6      369508  Bliss Hammocks - 60 Wide Cotton Rope Hammock -...
# 7      406681   Continental - CrossContact LX25, 235/60R18, 103H
# 8      425669     LumiSource - Cylinder Ash Wood Table Lamp, Ash
# 9      373605  Julia Jewelry - Round Cut Black Diamond Studs ...
#
#   product_added_date           brand    current_vendor  \
# 0         2024-09-04          Adesso               D&H
# 1         2019-04-12         PetSafe  UTM Distributing
# 2         2024-06-19           Bloem        Flat River
# ...
